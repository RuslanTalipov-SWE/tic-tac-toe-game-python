# %%
# Tic Tac Toe in Python
    
from IPython.display import clear_output    
clear_output 

board = ['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']

def player_board(board):
    print('Sample Board         Your Board \n')
    print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print(' -----------    |    -----------')
    print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print(' -----------    |    -----------')
    print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')
    
   
    player_move = 'no_number'
    within_range = False
    
    while player_move.isdigit() == False or within_range == False:
        player_move = input('Player please put X to position from 1 to 9: ')
        if player_move.isdigit() == False:
            clear_output()
            print('Sorry but you did not enter an integer. Please try again.')
            
            print('Sample Board         Your Board \n')
            print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
            print(' -----------    |    -----------')
            print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
            print(' -----------    |    -----------')
            print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')
    
            
        
        if player_move.isdigit() == True:
            if int(player_move) in range(1,10):
                
                clear_output()
                board[int(player_move)] = 'X'
                
                print('Sample Board         Your Board \n')
                print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
                print(' -----------    |    -----------')
                print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
                print(' -----------    |    -----------')
                print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')
               
    
            else:
                within_range = False
                clear_output()
                print('Sorry but your number is out of range. Please try again.')
                
                print('Sample Board         Your Board \n')
                print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
                print(' -----------    |    -----------')
                print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
                print(' -----------    |    -----------')
                print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')

                   
        if board[1] == board[2] == board[3] == 'X' or board[4] == board[5] == board[6] == 'X' or board[7] == board[8] == board[9] == 'X' or board[1] == board[2] == board[3] == '0' or board[4] == board[5] == board[6] == '0' or board[7] == board[8] == board[9] == '0':
            
            print('Congratulations! You win!!!')
            break
            
            
            
        else:
            player_move = input('Player please put 0 to position from 1 to 9: ')
            if player_move.isdigit() == False:
                clear_output()
                print('Sorry but you did not enter an integer. Please try again.')
            
                print('Sample Board         Your Board \n')
                print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
                print(' -----------    |    -----------')
                print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
                print(' -----------    |    -----------')
                print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')
    
            
        
            if player_move.isdigit() == True:
                if int(player_move) in range(1,10):
                
                    clear_output()
                    board[int(player_move)] = '0'
                
                    print('Sample Board         Your Board \n')
                    print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
                    print(' -----------    |    -----------')
                    print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
                    print(' -----------    |    -----------')
                    print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')
               
    
                else:
                    within_range = False
                    clear_output()
                    print('Sorry but your number is out of range. Please try again.')
                
                    print('Sample Board         Your Board \n')
                    print('  7 | 8 | 9     |     ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
                    print(' -----------    |    -----------')
                    print('  4 | 5 | 6     |     ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
                    print(' -----------    |    -----------')
                    print('  1 | 2 | 3     |     ' + board[1] + ' | ' + board[2] + ' | ' + board[3] + '\n')

                   
            if board[1] == board[2] == board[3] == 'X' or board[4] == board[5] == board[6] == 'X' or board[7] == board[8] == board[9] == 'X' or board[1] == board[2] == board[3] == '0' or board[4] == board[5] == board[6] == '0' or board[7] == board[8] == board[9] == '0':
            
                print('Congratulations! You win!!!')
                break

# %%
player_board(board)
# Out:
# Sample Board         Your Board
#
#   7 | 8 | 9     |     X | 0 | X
#  -----------    |    -----------
#   4 | 5 | 6     |     0 | X | 0
#  -----------    |    -----------
#   1 | 2 | 3     |     0 | 0 | 0
#
# Congratulations! You win!!!
